# %% [markdown]
# # General Testing
#
# The following code install the libraries we will use in the workshop. Might be helpful in debugging.
#
# Tests are included for PyTorch and TensorFlow.
#
# # Tests généraux
#
# Les lignes de code suivantes installent les librairies que nous utiliserons dans l'atelier. Cela peut être utile pour débugguer.
#
# Des tests sont inclus pour PyTorch et TensorFlow.

# %%
import tensorflow as tf

# %%
import PIL
import torch
# !pip install transformers
import transformers

# %% [markdown]
# ## Test for PyTorch
#
# Should display:
#   `tensor([[1, 2, 3],
#         [4, 5, 6]])`

# %%
x = torch.tensor([[1, 2, 3], [4, 5, 6]])
print(x)

# %% [markdown]
# ## Test for TensorFlow
#
# Should display: `tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)`

# %%
y = tf.constant([[1, 2, 3], [4, 5, 6]])
print(y)
